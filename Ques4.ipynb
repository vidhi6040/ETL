# %%
import pandas as pd

# %%
data = pd.read_csv("C:\\Users\\mailt\\Desktop\\Diya\\Projects\\ETL\\transactions_cleaned.csv")

# %%
top_10_customers = (data
                    .groupby("customer_id")
                    .agg(total_amount=("amount", "sum"), total_transactions=("transaction_id", "count"))
                    .sort_values("total_amount", ascending=False)
                    .head(10))
top_10_customers
# Out:
#              total_amount  total_transactions
# customer_id
# cust490           8601.48                  19
# cust121           8398.68                  24
# cust396           8276.56                  21
# cust161           8207.95                  22
# cust354           8198.74                  17
# cust108           7568.74                  15
# cust337           7554.64                  18
# cust345           7437.97                  24
# cust438           7403.59                  21
# cust321           7394.70                  23
